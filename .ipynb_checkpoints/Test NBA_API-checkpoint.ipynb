# %% [markdown]
# # Import libraries

# %%
import nba_api
import pandas as pd
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.static import players
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Configure matplotlib

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = (18, 10)
plt.style.use('rose-pine-dawn.mplstyle')
plt.rcParams['lines.linestyle'] = '--'

# %% [markdown]
# ### 1. Charting player stats over their careers

# %% [markdown]
# Function to get career stats for a player in the <b> regular season </b>

# %%
def get_career_stats(player_name: str):
    """ Takes as input a player name and returns the corresponding career stats as a pandas dataframe """
    
    player_id = players.find_players_by_full_name(player_name)[0]['id']

    career = playercareerstats.PlayerCareerStats(player_id).get_data_frames()[0]
    
    return career

# %%
ex = get_career_stats("D'Angelo Russel")

# %%
player_stats_dict = {}
player_stats_dict['GP'] = 'Games Played'
player_stats_dict['GS'] = 'Games Started'
player_stats_dict['MIN'] = 'Minutes Played'
player_stats_dict['FGM'] = 'Field Goals Made'
player_stats_dict['FGA'] = 'Field Goals Attempted'
player_stats_dict['FG_PCT'] = 'Field Goal Percent'
player_stats_dict['FG3M'] = '3 Point Field Goals Made'
player_stats_dict['FG3A'] = '3 Point Field Goals Attempted'
player_stats_dict['FG3_PCT'] = '3 Point Field Goal Percent'
player_stats_dict['FTM'] = 'Free Throws Made'
player_stats_dict['FTA'] = 'Free Throws ATtempted'
player_stats_dict['FT_PCT'] = 'Free Throw Percent'
player_stats_dict['OREB'] = 'Offensive Rebounds'
player_stats_dict['DREB'] = 'Defensive Rebounds'
player_stats_dict['REB'] = 'Rebounds'
player_stats_dict['AST'] = 'Assists'
player_stats_dict['STL'] = 'Steals'
player_stats_dict['BLK'] = 'Blocks'
player_stats_dict['TOV'] = 'Turnovers'
player_stats_dict['PF'] = 'Personal Fouls'
player_stats_dict['PTS'] = 'Points'

# %%
from nba_api.stats.static import players

def chart_career_stats(player_name: str, metric: str):
    """ Create a line graph of a player's career stats """
    
    # Get player stats
    career = get_career_stats(player_name)
    career = career.groupby('SEASON_ID').sum()
    career.reset_index(inplace=True)
    
    # Get corresponding career stats
    plt.plot(career['SEASON_ID'], career[metric], label=player_stats_dict[metric])
    plt.title(f'{player_name} Career Stats', fontsize=18)
    plt.xlabel('NBA Season', fontsize=15)
    plt.ylabel(f"{player_stats_dict[metric]} Number", fontsize=15)
    plt.legend(fontsize=15)
    plt.show()

# %%
chart_career_stats("D'Angelo Russel", 'REB')

# %%
ex = ex.groupby(['SEASON_ID']).sum()
ex['SEASON_ID'] = ex.index
ex
# Out:
#            PLAYER_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE   GP  \
# SEASON_ID
# 2015-16      1626156        00  1610612747               LAL        20.0   80
# 2016-17      1626156        00  1610612747               LAL        21.0   63
# 2017-18      1626156        00  1610612751               BKN        22.0   48
# 2018-19      1626156        00  1610612751               BKN        23.0   81
# 2019-20      4878468    000000  3221225494         GSWMINTOT        72.0   90
# 2020-21      1626156        00  1610612750               MIN        25.0   42
# 2021-22      1626156        00  1610612750               MIN        26.0   65
# 2022-23      4878468    000000  3221225497         MINLALTOT        81.0  142
# 2023-24      1626156        00  1610612747               LAL        27.0   48
#
#             GS     MIN  FGM   FGA  ...  OREB  DREB  REB  AST  STL  BLK  TOV  \
# SEASON_ID                          ...
# ...

# %% [markdown]
# # Teams

# %%
from nba_api.stats.static import teams
teams = teams.get_teams()
teams = pd.DataFrame(teams)
teams

# %% [markdown]
# # Scoreboard

# %%
from nba_api.live.nba.endpoints import scoreboard

# Today's Score Board
games = scoreboard.ScoreBoard()

games.get_json()
